# %% [markdown]
# <a href="https://colab.research.google.com/github/jrebull/MIAAD/blob/main/MIAAD_Prope_Proyecto_p2_Algoritmos_Javier_Rebull.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div align="center">
#
# 🎓
# # **Universidad Autónoma de Ciudad Juárez**
# ## **Maestría en Inteligencia Artificial y Analítica de Datos (MIAAD)**
# <br><br>
#
# ---
# <br>
#
# # 💻 *Parte 02 Proyecto - Análisis Teórico vs Análisis Empírico* 🐍
# <br>
#
# ### MÓDULO 4: Análisis de Algoritmos
# <br>
#
# ---
# <br>
#
# 🧑‍🏫 **Profesor Titular:** Dr. Gilberto Rivera Zárate
# <br><br>
#
# ---
# <br>
#
# 🧑‍🎓 **Estudiante:**
# ## **Javier Augusto Rebull Saucedo**
# Candidato a Entrar al Postgrado
# <br><br>
#
# </div>
#
# ---
#
# <div align="right">
# 📚 Curso Propedéutico - MIAAD
# <br>
# 📅 28 de mayo de 2025
# </div>
#
#
#
#
#
# ---
#
# 1.  Programa un algoritmo que multiplique dos matrices.
#     * Por simplicidad, considera solo matrices cuadradas n x n.
#     * Puedes utilizar el lenguaje de tu preferencia.
#     * No se permite utilizar instrucciones ni bibliotecas que automatizan la multiplicación de arreglos, vectores, o matrices.
#     * Las matrices deben inicializar sus n x n elementos aleatoriamente.
#
#
# 3.	Modifica el código para que haga un conteo de las veces que se ejecuta el ciclo más interno del programa.
# ---

# %% [markdown]
# ## Definicion de Librerias, (no para calculo de multiplicacion de matrices)

# %%
import random # Importamos la biblioteca random para generar números aleatorios

# %% [markdown]
# # Inciamos la Definicion de Funciones

# %% [markdown]
# #### Función para Generar Matrices Aleatorias
#
# Esta función se encarga de crear una matriz cuadrada ($n \times n$) con elementos generados aleatoriamente.
#
# **Características:**
#
# * Crea una matriz cuadrada de dimensiones $n \times n$.
# * Los elementos de la matriz se inicializan con valores enteros aleatorios.
# * Dichos valores aleatorios están comprendidos entre `valor_min` y `valor_max` (ambos inclusive).

# %%
def crear_matriz_aleatoria(n, valor_min=0, valor_max=9):
    matriz = []
    for _ in range(n):  # Itera para cada fila
        fila_actual = []
        for _ in range(n):  # Itera para cada columna en la fila actual
            # Genera un número aleatorio para el elemento de la matriz
            elemento_aleatorio = random.randint(valor_min, valor_max)
            fila_actual.append(elemento_aleatorio)
        matriz.append(fila_actual)
    return matriz

# %% [markdown]
# ### Funcion para Imprimir la Matriz en pantalla de manera amistosa

# %%
def imprimir_matriz(matriz, nombre_matriz="Matriz"):
    print(f"\n{nombre_matriz}:")
    if not matriz or not matriz[0]:
        print("Error ---- Matriz vacía o inválida ----")
        return

    ancho_columna = 4 # Ancho para alinear números

    for fila in matriz:
        for elemento in fila:
            print(str(elemento).rjust(ancho_columna), end=" ")


        print()

# %% [markdown]
# ### Definimos la Función para el Cálculo de Matrices
#
# * Multiplica dos matrices cuadradas (`matriz_a` * `matriz_b`).
# * Las matrices deben ser de la misma dimensión $n \times n$.
# * No utilizamos ninguna biblioteca que automatice la multiplicación.
#
# ---
#
# Posteriormente, se realiza una verificación básica de dimensiones (aunque el problema asume que las matrices son cuadradas y de dimensiones correctas).
#
# ### **Hemos modificado para poder Devolver la matriz resultado y el conteo de ejecuciones del ciclo más interno.**

# %%
def multiplicar_matrices(matriz_a, matriz_b):

    n = len(matriz_a)

    if n == 0 or len(matriz_a[0]) != n or len(matriz_b) != n or len(matriz_b[0]) != n:
        print("Error: Las matrices no son cuadradas o no tienen las mismas dimensiones.")
        return [], 0 # Devuelve matriz vacía y conteo cero en caso de error

    matriz_resultado = []
    for _ in range(n):
        fila_resultado_ceros = [0] * n
        matriz_resultado.append(fila_resultado_ceros)

    contador_ciclo_interno = 0 # 1. Inicializar el contador

    for i in range(n):
        for j in range(n):
            suma_para_elemento_ij = 0
            for k in range(n):  # Este es el ciclo más interno
                suma_para_elemento_ij += matriz_a[i][k] * matriz_b[k][j]
                contador_ciclo_interno += 1 # 2. Incrementar el contador en cada iteración
            matriz_resultado[i][j] = suma_para_elemento_ij

    return matriz_resultado, contador_ciclo_interno # 3. Devolver la matriz y el contador

# %% [markdown]
# ### Función Principal
#
# Esta es la Función Principal que nos va a ayudar a tener un Menú principal e invocar a nuestras funciones que hemos definido para:
#
# * Creación aleatoria de Matriz
# * Impresión de Matriz
# * Multiplicación de matriz
#
# > Función principal que maneja el menú y el flujo del programa.
#
#
# ### En `main()`:
#
# * La llamada a `multiplicar_matrices` ahora desempaqueta dos valores: `matriz_producto, conteo_operaciones_interno = multiplicar_matrices(matriz_1, matriz_2)`.
# * Después de imprimir la matriz resultado, se añade una línea para mostrar el valor de `conteo_operaciones_interno`.
# * También se añade una pequeña nota que indica que este conteo es $n^3$, lo cual es esperado para este algoritmo.

# %%
# --- Programa Principal (Menusito)  V2---
def main():

    print("=====================================================")
    print("  Multiplicador de Matrices Cuadradas (n x n)  ")
    print("         (Usando 'random' para inicializar)      ")
    print("=====================================================")

    while True:
        print("\n-----------------------------------------------------")
        entrada_usuario = input("Introduce el tamaño (n) para las matrices cuadradas "
                                "(o escribe 'salir' para terminar): ")

        if entrada_usuario.lower() == 'salir':
            print("¡Gracias por usar el programa! Adiós.")
            break

        try:
            n = int(entrada_usuario)
            if n <= 0:
                print("El valor de n debe ser un entero positivo.")
                continue
            if n > 15:
                print(f"Advertencia: n={n} es grande. La generación e impresión de matrices puede ser lenta.")
                confirmacion = input("¿Deseas continuar? (s/N): ")
                if confirmacion.lower() != 's':
                    continue
        except ValueError:
            print("Entrada inválida. Debes introducir un número entero para n.")
            continue

        print(f"\nGenerando dos matrices ({n}x{n}) con elementos aleatorios (0-9)...")

        matriz_1 = crear_matriz_aleatoria(n, 0, 9)
        matriz_2 = crear_matriz_aleatoria(n, 0, 9)

        imprimir_matriz(matriz_1, "Matriz A")
        imprimir_matriz(matriz_2, "Matriz B")

        print("\nCalculando el producto (Matriz A * Matriz B)...")
        # Ahora multiplicar_matrices devuelve dos valores: la matriz y el conteo
        matriz_producto, conteo_operaciones_interno = multiplicar_matrices(matriz_1, matriz_2)

        if matriz_producto: # Si la matriz producto no está vacía (es decir, no hubo error)
            imprimir_matriz(matriz_producto, "Matriz Resultado (A * B)")
            # 3. Mostrar el conteo
            print(f"\nEl ciclo más interno (k) se ejecutó {conteo_operaciones_interno} veces.")
            if n > 0:
                print(f"(Esto es igual a n*n*n = {n}*{n}*{n} = {n**3})")


if __name__ == "__main__":
    main()
# Out:
# =====================================================
#   Multiplicador de Matrices Cuadradas (n x n)
#          (Usando 'random' para inicializar)
# =====================================================
#
# -----------------------------------------------------
# Introduce el tamaño (n) para las matrices cuadradas (o escribe 'salir' para terminar): 1
#
# Generando dos matrices (1x1) con elementos aleatorios (0-9)...
#
# Matriz A:
#    5
#
# Matriz B:
#    6
#
# Calculando el producto (Matriz A * Matriz B)...
#
# Matriz Resultado (A * B):
#   30
#
# El ciclo más interno (k) se ejecutó 1 veces.
# (Esto es igual a n*n*n = 1*1*1 = 1)
#
# -----------------------------------------------------
# Introduce el tamaño (n) para las matrices cuadradas (o escribe 'salir' para terminar): 15
#
# Generando dos matrices (15x15) con elementos aleatorios (0-9)...
#
# Matriz A:
#    3    4    8    8    7    2    0    2    2    1    2    1    7    5    6
#    8    1    0    8    9    3    6    7    4    2    8    6    8    2    3
#    0    5    8    5    4    4    9    0    6    4    4    1    0    4    9
#    4    2    4    0    7    7    6    4    1    2    5    1    0    1    6
#    9    2    0    1    4    2    3    9    6    0    0    6    7    9    7
#    1    1    7    3    3    1    1    5    0    5    1    8    7    3    3
#    3    6    5    5    9    7    2    0    4    2    3    8    6    6    4
#    4    5    2    5    7    2    1    9    1    9    4    6    1    2    2
#    1    1    8    7    6    5    0    0    1    0    2    0    4    7    7
#    4    3    5    5    0    9    0    8    7    4    5    1    8    0    2
#    8    2    6    6    0    1    2    1    0    4    8    4    7    7    1
#    6    9    1    3    1    0    6    4    7    8    8    5    5    3    0
#    5    7    5    8    0    7    9    3    5    6    0    3    4    5    3
#    1    2    3    1    3    7    3    4    3    3    4    2    1    1    0
#    2    9    1    8    3    1    8    3    9    4    6    6    3    6    5
#
# Matriz B:
#    0    7    1    1    5    7    5    9    9    2    1    0    3    5    4
#    4    0    7    4    7    8    7    5    8    7    1    9    1    9    8
#    0    3    3    6    7    3    0    4    4    2    2    5    9    7    2
#    3    8    8    0    0    0    6    1    3    9    5    5    9    5    9
#    8    0    0    5    1    3    7    1    1    2    0    9    0    5    9
#    5    8    9    6    0    6    5    4    4    9    2    4    7    6    5
#    8    3    9    5    3    2    3    1    4    7    9    0    5    2    1
#    7    1    3    2    0    6    8    2    9    4    4    4    6    3    8
#    0    3    1    1    2    0    9    1    3    0    3    1    1    6    0
#    4    7    2    7    3    4    9    2    3    2    4    1    8    1    7
#    5    7    6    7    2    5    0    2    0    9    5    3    1    8    7
#    6    1    0    4    1    8    1    3    7    6    0    0    1    0    6
#    8    4    7    6    2    1    8    7    0    5    5    9    9    7    7
#    8    5    3    3    7    3    0    4    5    9    3    0    3    3    4
#    5    7    9    3    1    6    9    3    1    8    1    9    0    9    1
#
# Calculando el producto (Matriz A * Matriz B)...
#
# Matriz Resultado (A * B):
#  266  250  277  220  173  202  304  204  195  316  151  321  274  347  323
#  391  320  326  280  143  291  398  241  285  404  246  299  302  364  443
#  278  281  347  262  192  228  312  159  209  361  210  265  250  353  253
#  252  218  251  226  119  235  250  151  190  277  143  217  179  272  241
#  339  251  248  202  174  287  363  255  317  332  170  235  223  308  310
#  253  182  187  217  130  206  235  169  199  245  134  208  257  214  280
#  349  275  303  291  193  292  337  237  263  393  163  318  267  366  386
#  298  230  213  240  140  286  341  174  283  296  159  236  251  258  395
#  231  244  258  194  144  164  225  161  141  302  124  264  234  299  247
#  249  294  304  244  131  238  362  218  245  312  196  261  333  345  331
#  251  295  253  236  198  228  214  236  227  333  189  186  285  290  315
#  295  264  277  269  209  282  348  222  295  334  229  210  255  320  361
#  309  322  373  263  213  269  369  234  318  398  246  242  358  338  337
#  182  162  177  176   86  165  186  108  156  205  120  136  174  187  204
#  353  296  359  265  208  283  387  203  300  431  250  272  259  374  374
#
# El ciclo más interno (k) se ejecutó 3375 veces.
# (Esto es igual a n*n*n = 15*15*15 = 3375)
#
# -----------------------------------------------------
# Introduce el tamaño (n) para las matrices cuadradas (o escribe 'salir' para terminar): 20
# Advertencia: n=20 es grande. La generación e impresión de matrices puede ser lenta.
# ¿Deseas continuar? (s/N): s
#
# Generando dos matrices (20x20) con elementos aleatorios (0-9)...
#
# Matriz A:
#    4    3    4    5    6    7    2    8    5    5    0    2    8    8    2    3    7    6    7    8
#    7    6    5    2    9    9    9    1    9    5    1    5    5    7    4    6    4    4    4    9
#    9    8    6    3    9    5    2    4    5    4    0    5    5    6    6    1    2    7    9    7
#    7    8    7    9    4    7    0    7    7    1    0    9    1    3    5    6    1    7    2    9
#    5    6    5    6    9    1    9    8    8    8    3    1    0    9    5    3    1    3    2    7
#    8    0    3    8    1    9    7    9    0    8    0    0    8    7    3    0    1    4    0    8
#    2    7    7    9    3    3    3    1    1    5    5    3    0    7    9    4    1    7    3    7
#    8    3    6    4    8    4    6    6    7    7    9    4    4    3    4    1    3    6    5    9
#    5    9    9    0    2    0    9    1    4    4    1    8    3    2    6    1    5    0    1    6
#    5    1    0    2    0    0    0    1    0    0    7    5    9    1    8    6    3    9    1    4
#    7    6    2    4    3    1    1    0    7    3    8    8    7    5    9    2    9    8    6    8
#    6    0    4    5    3    1    2    2    8    9    3    7    5    8    9    2    6    3    1    8
#    8    4    8    4    6    5    9    4    4    4    5    2    8    0    8    0    7    6    4    7
#    5    8    3    3    6    6    3    8    6    5    2    3    9    7    5    2    1    7    0    2
#    7    0    1    8    3    6    3    7    9    0    8    7    1    7    6    7    0    4    4    9
#    1    1    4    2    6    4    0    8    9    7    1    3    1    1    4    1    3    6    4    4
#    4    5    4    4    9    9    9    6    9    4    8    1    7    4    5    5    4    9    6    1
#    5    5    3    9    3    1    8    3    2    6    1    2    4    4    4    6    5    7    8    0
#    0    8    1    3    8    3    2    8    8    7    6    2    8    3    7    0    9    3    3    5
#    2    7    9    9    6    5    1    9    6    3    6    1    9    5    4    0    2    6    1    3
#
# Matriz B:
#    6    9    9    2    1    7    9    6    0    8    9    9    0    9    7    5    6    9    1    8
#    2    8    5    8    4    7    0    3    0    3    9    5    1    7    1    2    5    4    6    7
#    1    9    1    3    5    0    9    0    9    3    8    9    8    1    0    3    7    0    4    1
#    3    5    9    9    6    6    9    9    1    2    0    2    4    4    0    3    3    5    8    4
#    2    5    2    5    3    4    2    3    3    6    6    9    2    4    6    6    1    2    9    2
#    1    4    5    5    8    1    9    0    2    3    2    8    4    1    2    1    7    1    7    5
#    4    0    0    0    7    7    3    1    1    1    5    0    5    4    6    8    5    2    1    5
#    6    4    0    8    9    2    9    7    0    7    3    5    9    2    6    9    4    6    2    9
#    7    4    0    6    1    7    1    5    0    0    0    2    9    0    1    4    4    5    3    5
#    9    7    6    8    4    9    4    9    3    6    3    4    1    2    1    7    0    2    9    8
#    3    5    6    9    5    4    5    8    2    9    9    6    7    2    0    3    7    0    9    0
#    7    2    2    6    4    4    2    3    3    0    4    0    8    6    5    6    6    9    0    4
#    9    0    2    3    3    8    8    7    3    2    8    3    4    1    3    1    9    2    3    2
#    1    0    4    8    7    5    8    9    9    6    8    8    6    0    9    7    6    4    0    8
#    2    2    2    6    6    4    5    3    0    0    5    2    5    7    1    0    9    4    1    6
#    5    1    0    8    4    8    4    3    6    7    5    4    3    5    6    6    0    6    9    8
#    8    2    3    4    5    3    7    7    5    7    9    9    5    8    1    9    0    0    8    8
#    8    6    1    3    3    3    2    1    8    7    9    5    2    0    7    8    7    1    8    6
#    7    2    2    9    9    0    4    4    3    3    4    7    4    6    2    2    4    2    9    0
#    7    9    5    9    7    2    2    9    9    9    5    3    7    4    2    0    2    7    4    7
#
# Calculando el producto (Matriz A * Matriz B)...
#
# Matriz Resultado (A * B):
#  526  413  314  605  535  419  554  528  386  477  540  547  473  325  356  458  435  347  511  543
#  525  472  340  614  536  526  515  491  392  472  600  558  502  398  402  482  492  413  524  590
#  498  493  343  601  505  434  498  468  354  449  594  564  439  400  369  422  499  395  493  521
#  463  509  341  624  491  423  498  449  342  424  501  475  490  377  333  409  468  459  464  557
#  441  454  316  606  505  488  471  519  319  454  510  480  474  331  364  490  407  379  455  560
#  421  376  339  469  472  398  554  476  283  405  426  412  376  251  319  379  413  323  352  504
#  354  418  325  566  461  380  429  423  344  386  491  418  393  314  256  342  421  304  454  451
#  541  522  367  629  524  471  525  545  351  522  596  546  515  370  343  474  492  378  543  521
#  361  356  222  392  360  364  332  320  249  272  465  335  378  341  222  328  369  297  278  402
#  359  232  198  352  270  305  312  313  229  306  422  267  272  247  223  246  358  239  302  312
#  565  443  363  627  477  475  478  550  360  467  639  502  489  430  311  424  515  387  508  523
#  493  390  323  557  429  455  472  533  336  398  488  420  463  333  291  409  417  374  389  517
#  515  472  333  525  508  449  544  467  323  447  612  522  472  399  305  431  517  324  495  499
#  436  386  281  518  431  454  474  437  272  388  518  455  406  276  344  415  472  330  407  506
#  455  401  333  638  505  426  503  515  311  449  463  438  525  336  351  407  462  442  436  513
#  383  332  179  436  348  284  328  336  225  308  318  352  364  204  214  340  289  243  376  374
#  534  441  316  627  560  519  560  486  331  486  620  579  516  353  386  522  549  327  615  539
#  442  329  281  494  439  431  443  410  270  359  472  411  338  346  302  431  369  290  474  452
#  493  388  284  590  466  443  441  517  257  416  519  465  458  333  251  418  409  290  502  493
#  417  440  311  568  471  411  539  475  303  403  521  490  473  258  269  389  490  292  475  446
#
# El ciclo más interno (k) se ejecutó 8000 veces.
# (Esto es igual a n*n*n = 20*20*20 = 8000)
#
# -----------------------------------------------------
# Introduce el tamaño (n) para las matrices cuadradas (o escribe 'salir' para terminar): salir
# ¡Gracias por usar el programa! Adiós.
