# %% [markdown]
# <a href="https://colab.research.google.com/github/jrebull/MIAAD/blob/main/MIAAD_Prope_Practica_04_Python_Javier_Rebull.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div align="center">
#
# 🎓
# # **Universidad Autónoma de Ciudad Juárez**
# ## **Maestría en Inteligencia Artificial y Analítica de Datos (MIAAD)**
# <br><br>
#
# ---
# <br>
#
# # 💻 *Practica 4. Calculador de Impuestos* 🐍
# <br>
#
# ### MÓDULO 3: Programación
# <br>
#
# ---
# <br>
#
# 🧑‍🏫 **Profesor Titular:** Dr. Luis Carlos Méndez González
# <br><br>
#
# ---
# <br>
#
# 🧑‍🎓 **Estudiante:**
# ## **Javier Augusto Rebull Saucedo**
# Candidato a Entrar al Postgrado
# <br><br>
#
# </div>
#
# ---
#
# <div align="right">
# 📚 Curso Propedéutico - MIAAD
# <br>
# 📅 01 de junio de 2025
# </div>
#
#
#
#
#
# ---
#
# Crea un programa que pida al usuario que ingrese su ingreso anual y calcule el impuesto que debe pagar según las siguientes tasas:
#
# * Menos de 10,000: 0%
# * De 10,000 a 20,000: 10%
# * De 20,001 a 50,000: 20%
# * Más de 50,000: 30%
#
# **Instrucciones:**
#
# * Pide al usuario que ingrese su ingreso anual.
# * Usa `if` para verificar si el ingreso es un número negativo.
# * Usa `if-elif-else` para determinar el porcentaje de impuesto y calcular el monto a pagar.
# * Recuerde enviar su `.py` y capturas de pantalla de los resultados obtenidos
#
# ---

# %%
def calcular_impuesto(ingreso_anual):
    """Funcion para hacer el Calculo de las tasas"""

    #aqui inicializo las variables para que no se contaminen si las vuelvo a usar
    tasa_impuesto = 0
    impuesto_a_pagar = 0


    #Usando IF/ELIF/ELSE hacemos muy facil la determinacion de la tasa de impuesto
    if ingreso_anual < 0:
        print("Error: El ingreso anual no puede ser un número negativo.")
        tasa_impuesto = 0
        impuesto_a_pagar = 0
    elif ingreso_anual < 10000:
        tasa_impuesto = 0.00
    elif ingreso_anual <= 20000:
        tasa_impuesto = 0.10
    elif ingreso_anual <= 50000:
        tasa_impuesto = 0.20
    else:  # Más de 50,000
        tasa_impuesto = 0.30


    # Solo calculamos si el monto es Positivo, si es negativo, pues nada
    if ingreso_anual >= 0:
        impuesto_a_pagar = ingreso_anual * tasa_impuesto

    #regresamos de la funcion los valores de la tasa que le corresponde y el varo a pagar
    return tasa_impuesto, impuesto_a_pagar

def main():
    """Creamos esta funcion principal para poder hacer muchos calculos"""
    print("Programa de Cálculo de Impuestos Anuales")
    print("----------------------------------------")

    for i in range(10): #voy hacer 10 calculos
        print(f"\n--- Cálculo de Impuestos #{i + 1} ---")

        try:
            ingreso_str = input(f"({i + 1}/5) Indique $$$$$, ingrese su ingreso anual: $")
            ingreso_anual_usuario = float(ingreso_str)

            tasa, impuesto = calcular_impuesto(ingreso_anual_usuario)

            print(f"Ingreso Anual Ingresado: ${ingreso_anual_usuario:,.2f}")
            if ingreso_anual_usuario >= 0: # Solo mostrar tasa e impuesto si el ingreso es válido
                print(f"Tasa de Impuesto Aplicada: {tasa*100:.0f}%")
                print(f"Impuesto a Pagar: ${impuesto:,.2f}")
            # El mensaje de error para ingresos negativos ya se maneja en calcular_impuesto

        except ValueError:
            print("Error: Valor Invalido. mete tu salario en un monto real porfa.")
        except Exception as e:
            print(f"Ha ocurrido un error inesperado FATALITYYYY: {e}")

        print("----------------------------------------")

    print("\nSe han completado los 10 cálculos de impuestos.")

    print("\nA tope con el propedeutico.")

if __name__ == "__main__":
    main()
# Out:
# Programa de Cálculo de Impuestos Anuales
# ----------------------------------------
#
# --- Cálculo de Impuestos #1 ---
# (1/5) Indique $$$$$, ingrese su ingreso anual: $-100
# Error: El ingreso anual no puede ser un número negativo.
# Ingreso Anual Ingresado: $-100.00
# ----------------------------------------
#
# --- Cálculo de Impuestos #2 ---
# (2/5) Indique $$$$$, ingrese su ingreso anual: $0
# Ingreso Anual Ingresado: $0.00
# Tasa de Impuesto Aplicada: 0%
# Impuesto a Pagar: $0.00
# ----------------------------------------
#
# --- Cálculo de Impuestos #3 ---
# (3/5) Indique $$$$$, ingrese su ingreso anual: $9999
# Ingreso Anual Ingresado: $9,999.00
# Tasa de Impuesto Aplicada: 0%
# Impuesto a Pagar: $0.00
# ----------------------------------------
#
# --- Cálculo de Impuestos #4 ---
# (4/5) Indique $$$$$, ingrese su ingreso anual: $10000
# Ingreso Anual Ingresado: $10,000.00
# Tasa de Impuesto Aplicada: 10%
# Impuesto a Pagar: $1,000.00
# ...
